# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
producto = ("Taza")
precio = (4500 )
stock = (25)

# %%
total = precio * stock

# %%
print(total, type(total))
# Out:
# 112500 <class 'int'>

# %%
codigo = "A123"
cantidad = 5
codigo + cantidad
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1051/488869269.py in <cell line: 0>()
#       1 codigo = "A123"
#       2 cantidad = 5
# ----> 3 codigo + cantidad
#
# TypeError: can only concatenate str (not "int") to str

# %%
resultado_texto = codigo + str(cantidad)
print(resultado_texto)
# Out:
# A1235

# %%
cantidad_extra = 10
print(cantidad + cantidad_extra)
# Out:
# 15

# %%
temperatura = 35
alerta = temperatura >= 35
print (alerta) #si uso > como operador entonces si esta en 35 no lo registraria y daria FALSE#
# Out:
# True

# %%
nota1 = 6
nota2 = 6
nota3 = 6

promedio = (nota1 + nota2 + nota3) / 3
aprobado = promedio >= 6
print(promedio , aprobado)
#Si el operador fuese > 6 entonces estaraia desaprobado y daria FALSE como salida#
# Out:
# 6.0 True

# %%
if alerta:
  print("Activar alerta de calor")
else:
  print("Temperatura normal")
# Out:
# Activar alerta de calor
