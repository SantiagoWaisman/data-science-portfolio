# %%
notas = [ 6 , 8 , 4 , 9 , 7 ]
for i in notas:
  if i >= 6:
    print("Aprobado")
  else:
    print ("Desaprobado")
# Out:
# Aprobado
# Aprobado
# Desaprobado
# Aprobado
# Aprobado

# %%
productos = ["Taza", "Goma", "Lapicera"]
precios = [4500, 500, 1500]
stocks = [25, 120, 44]

# %%
for i in range(len(productos)):

    total = stocks [i] * precios [i]
    print(productos[i], precios [i] , stocks [i], "--El total es",  total)
    if stocks [i] < 30:
      print("STOCK BAJO")
# Out:
# Taza 4500 25 --El total es 112500
# STOCK BAJO
# Goma 500 120 --El total es 60000
# Lapicera 1500 44 --El total es 66000

# %%
notas = [6, 8, 4, 9, 7]
for i in notas:
  if i >= 9:
    print("Excelente")
  elif i >= 7:
    print("Muy Bueno")
  elif i >= 6:
    print("Aprobado")
  else:
    print("Desaprobado")
# Out:
# Aprobado
# Muy Bueno
# Desaprobado
# Excelente
# Muy Bueno

# %%
for i in range(len(productos)):
  if stocks[i] < 30 and precios[i] > 1000:
    print("reponer urgente")
  elif stocks[i] < 50 or precios[i] < 600:
    print("revisar")
  else:
    print("ok")

  #taza hay que reponer urgente las otras 2 revisar#
# Out:
# reponer urgente
# revisar
# revisar
